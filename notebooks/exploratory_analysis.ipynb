# %% [markdown]
# #### Exploration of customer purchasing behavior

# %%
# Import standard python libraries
import pandas as pd
import os,sys

# Get the absolute path of the parent directory
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)

# %%
# Importing all functions and classes from the module.
from scripts.data_processing import *

# %%
# Load the datasets
df_store = pd.read_csv('../data/store.csv')
df_test = pd.read_csv('../data/test.csv')
df_train = pd.read_csv('../data/train.csv',low_memory=False)

# %% [markdown]
# ### Info About Dataset

# %%
# Create an instance of the DataProcessor class
processor = DataProcessor(df_store)

# %%
# Get the first 10 rows of the DataFrame
head_data = processor.get_head()
head_data
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
# Get the last 10 rows of the DataFrame
tail_data = processor.get_tail()
tail_data
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 1105   1106         a          c               5330.0
# 1106   1107         a          a               1400.0
# 1107   1108         a          a                540.0
# 1108   1109         c          a               3490.0
# 1109   1110         c          c                900.0
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1105                        9.0                    2011.0       1
# 1106                        6.0                    2012.0       1
# 1107                        4.0                    2004.0       0
# 1108                        4.0                    2011.0       1
# ...

# %%
# Get descriptive statistics of the DataFrame
description = processor.get_describe()
description
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %%
# Get the shape (dimensions) of the DataFrame (rows, columns)
shape = processor.get_shape()
shape
# Out:
# (1115, 10)

# %%
# Get the list of column names
columns = processor.get_columns()
columns
# Out:
# Index(['Store', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %% [markdown]
# Data Quality Assessment
#
# check for missing values, duplicates, and calculate the percentage of missing data for each column.

# %%
# Get missing values and their percentages for store dataset
missing_values = processor.get_missing_values()
missing_values
# Out:
#                            num_missing  percent_missing (%)
# CompetitionDistance                  3                 0.27
# CompetitionOpenSinceMonth          354                31.75
# CompetitionOpenSinceYear           354                31.75
# Promo2SinceWeek                    544                48.79
# Promo2SinceYear                    544                48.79
# PromoInterval                      544                48.79

# %%
# Get missing values and their percentages for store dataset
processor1 = DataProcessor(df_test)
missing_values = processor1.get_missing_values()
missing_values
# Out:
#       num_missing  percent_missing (%)
# Open           11                 0.03

# %%
# Get missing values and their percentages for store dataset
processor1 = DataProcessor(df_train)
missing_values = processor1.get_missing_values()
missing_values
# Out:
# Empty DataFrame
# Columns: [num_missing, percent_missing (%)]
# Index: []

# %% [markdown]
# Handle missing value

# %%
df_store['Promo2SinceWeek'] = df_store['Promo2SinceWeek'].fillna(0)
df_store['Promo2SinceYear'] = df_store['Promo2SinceYear'].fillna(0)
df_store['PromoInterval'] = df_store['PromoInterval'].fillna(0)

df_store['CompetitionOpenSinceYear'] = df_store['CompetitionOpenSinceYear'].fillna(0)
df_store['CompetitionOpenSinceMonth'] = df_store['CompetitionOpenSinceMonth'].fillna(0)

# %%
# Get missing values and their percentages for store dataset
missing_values = processor.get_missing_values()
missing_values# Get missing values and their percentages for store dataset
missing_values = processor.get_missing_values()
missing_values
# Out:
#                      num_missing  percent_missing (%)
# CompetitionDistance            3                 0.27

# %%
# find the most frequent value(mode) in the 'Open' column and replace the missing values 
mode_open = df_test['Open'].mode()[0]
df_test['Open'] = df_test['Open'].fillna(mode_open)

# %%
import logging
def add_month_year(df):
    '''
    Converts the 'Date' column to datetime and adds Year, Month, Day, WeekOfYear columns.
    '''
    logging.info('Calculating Year, Month, Day, WeekOfYear for Dataframe')
    
    # Convert 'Date' column to datetime if it isn't already
    if not pd.api.types.is_datetime64_any_dtype(df['Date']):
        df['Date'] = pd.to_datetime(df['Date'])
    
    new_df = df.copy()
    new_df['Year'] = new_df['Date'].dt.year
    new_df['Month'] = new_df['Date'].dt.month
    new_df['Day'] = new_df['Date'].dt.day
    new_df['WeekOfYear'] = new_df['Date'].dt.isocalendar().week  # Updated to use isocalendar() for week
    return new_df

# %%
### Closed stores with no sales will not be counted for forcaset
# train_df = train_df[(train_df.Open != 0) & (train_df.Sales != 0)]
train_df = add_month_year(df_train)
train_df.head()
# Out:
# [20/Sep/2024 21:03:13] INFO - Calculating Year, Month, Day, WeekOfYear for Dataframe
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday  Year  Month  Day  WeekOfYear
# 0              1  2015      7   31          31
# 1              1  2015      7   31          31
# 2              1  2015      7   31          31
# 3              1  2015      7   31          31
# 4              1  2015      7   31          31

# %%
### Store and Train
train_store = pd.merge(train_df, df_store, how='inner', on='Store')
train_store['StateHoliday'] = train_store['StateHoliday'].apply(lambda x: str(x))
train_store
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday  Year  ...  WeekOfYear  StoreType  \
# 0                  0              1  2015  ...          31          c
# ...

# %% [markdown]
# ### Getting Insightes

# %% [markdown]
# Check for distribution in both training and test sets - are the promotions distributed similarly between these two groups?

# %%
train_distribution = df_train.Promo.value_counts()
test_distribution = df_test.Promo.value_counts()

# Create a figure with two subplots
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Plot training distribution
ax[0].bar(train_distribution.index.astype(str), train_distribution)
ax[0].set_title("Promo Distribution on Training Set")
ax[0].set_xlabel("Promo")
ax[0].set_ylabel("Count")

# Plot testing distribution
ax[1].bar(test_distribution.index.astype(str), test_distribution)
ax[1].set_title("Promo Distribution on Testing Set")
ax[1].set_xlabel("Promo")
ax[1].set_ylabel("Count")

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# [20/Sep/2024 21:16:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [20/Sep/2024 21:16:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [20/Sep/2024 21:16:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [20/Sep/2024 21:16:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# Check & compare sales behavior before, during, and after holidays

# %%
# Filter the data for open stores in 2014
open_store = train_store[(train_store.Open == 1) & (train_store.Year == 2014)]

# Define months for Christmas and Easter
christmas_month = 12
easter_month = 4

# Filter data for December and April
christmas_data = open_store[open_store.Month == christmas_month]
easter_data = open_store[open_store.Month == easter_month]

# Filter around Christmas (Days 21 to 29)
around_christmas = christmas_data[(christmas_data['Day'] > 20) & (christmas_data['Day'] < 30)]
around_christmas = around_christmas[['Day', 'Sales']].groupby('Day').mean()

# Filter around Easter (Days 16 to 24)
around_easter = easter_data[(easter_data['Day'] > 15) & (easter_data['Day'] < 25)]
around_easter = around_easter[['Day', 'Sales']].groupby('Day').mean()

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Plot for Christmas sales
axs[0].bar(around_christmas.index, around_christmas['Sales'], color='green', alpha=0.7)
axs[0].set_title('Sales during Christmas (Dec 25)')
axs[0].set_xlabel('Day')
axs[0].set_ylabel('Average Sales')

# Plot for Easter sales
axs[1].bar(around_easter.index, around_easter['Sales'], color='blue', alpha=0.7)
axs[1].set_title('Sales during Easter (April 20)')
axs[1].set_xlabel('Day')
axs[1].set_ylabel('Average Sales')
# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# insight There were more sales before and after the Holidays, rather than on the holidays

# %% [markdown]
# What can you say about the correlation between sales and number of customers?

# %%
def heatmap(df,title='', annot=True):
  plt.figure(figsize=(12,6))
  plt.title(title)
  correlation = df.corr()
  sns.heatmap(correlation,square = True, linewidths = .5, cmap = "BuPu", annot=annot)
  return

heatmap(train_store[['Sales', 'Customers']], title='Correlation B/n Sales and Customers')

# %% [markdown]
# Insight : There is a high correlation b/n Sales and Customers. The more customers the more sales

# %% [markdown]
# How does promo affect sales? Are the promos attracting more customers? How does it affect already existing customers

# %%
plt.figure(figsize=(12, 7))
sns.catplot(data=train_store, x="Month", y="Sales", hue='Promo', kind='bar', height=7, aspect=1.5)

plt.title('Sales by Month with Promotions')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()
# Out:
# [20/Sep/2024 21:29:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [20/Sep/2024 21:29:58] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
plt.figure(figsize=(12, 7))
sns.catplot(data=train_store, x="Month", y="Customers", hue='Promo', kind='bar', height=7, aspect=1.5)

plt.title('Sales by Month with Promotions')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()Sales
# Out:
# [20/Sep/2024 21:32:50] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# [20/Sep/2024 21:32:54] INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# Insight: Having a promotion increase the Sales and also the customers

# %% [markdown]
# Could the promos be deployed in more effective ways? Which stores should promos
# be deployed in?

# %%
# Filter stores with promotions
store_with_promo = train_store[train_df.Promo == 1]

# Group by store and aggregate sales and customers
result = store_with_promo[['Store', 'Sales', 'Customers']].groupby('Store').agg({
    "Sales": "mean",
    "Customers": "sum"
})

# Calculate the 10th percentile of sales
low_sales = result['Sales'].quantile(0.1)  # least 10 percent sales
small_sales = result[result['Sales'] <= low_sales]

# Print number of stores with low sales
print(f"Number of Stores with less than {low_sales} mean sales are {small_sales.shape[0]}")

# Create a scatter plot of Stores and their average Sales
plt.scatter(result.index, result['Sales'])
plt.title('Stores and Average Sales on Promotion')
plt.xlabel('Store')
plt.ylabel('Average Sales')
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()
# Out:
# Number of Stores with less than 5143.545555555555 mean sales are 112
