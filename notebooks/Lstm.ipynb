# %%
# Add the parent directory to the system path 
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
train_df = pd.read_csv("../data/train.csv",low_memory=False)
test_df = pd.read_csv("../data/test.csv",low_memory=False)
store_df = pd.read_csv("../data/store.csv",low_memory=False)

# %% [markdown]
# Store Sales dataset into time series data

# %%
train_df['Date'] = pd.to_datetime(train_df['Date'])
data = train_df[['Date', 'Store', 'Sales']]

# Filter for a specific store (e.g., Store 1)
store_data = data[data['Store'] == 1]
store_data.set_index('Date', inplace=True)
store_data = store_data.resample('D').sum()

# %% [markdown]
# Series Data is Stationary

# %%
# Check stationarity for a specific store
# Perform the ADF test

check_stationarity(store_data['Sales'])
# Out:
# ADF Statistic: -4.3681043682
# p-value: 0.0003378835
# Critical Values:
# 	1%: -3.4374778690
# 	5%: -2.8646866842
# 	10%: -2.5684454927
# The time series is stationary

# %% [markdown]
# Check for autocorrelation and partial autocorrelation of your data

# %%
# Difference the series (store_data is a Series, no need to reference 'Sales')
adf_result = adfuller(store_data['Sales'])
if adf_result[1] >= 0.05:
    store_data['Sales'] = store_data['Sales'].diff().dropna()

# %% [markdown]
# autocorrelation and partial autocorrelation of your data

# %%
# Autocorrelation and Partial Autocorrelation plots
fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(store_data['Sales'].dropna(), lags=30, ax=ax[0])
plot_pacf(store_data['Sales'].dropna(), lags=30, ax=ax[1])
plt.show()

# %% [markdown]
# Transform the time series data into supervised learning data

# %%
# Define time steps
n_step = 30   # number of steps to use for prediction (30 days)
data_scaled = MinMaxScaler(feature_range=(-1, 1)).fit_transform(store_data['Sales'].values.reshape(-1, 1))
X, y = create_supervised_data(data_scaled, n_step)

# Reshape input to be [samples, n_steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
#  Scale your data in the (-1, 1) range

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(store_data['Sales'].values.reshape(-1, 1))

# Create dataset for LSTM
X, y = create_supervised_data(data_scaled, n_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# Build an LSTM Regression model to predict the next sale

# %%
# Build and train the LSTM model
model = build_lstm_model(n_step)

# %%
### Train the model
history = train_lstm_model(model, X, y)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - loss: 0.2118 - val_loss: 0.1578
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - loss: 0.1910 - val_loss: 0.1619
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.1681 - val_loss: 0.1554
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - loss: 0.1859 - val_loss: 0.1558
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.1830 - val_loss: 0.1561
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1840 - val_loss: 0.1527
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1743 - val_loss: 0.1568
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.1769 - val_loss: 0.1520
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.1777 - val_loss: 0.1519
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 0.1809 - val_loss: 0.1496
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - loss: 0.1776 - val_loss: 0.1546
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.1720 - val_loss: 0.1527
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - loss: 0.1885 - val_loss: 0.1548
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - loss: 0.1943 - val_loss: 0.1483
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.1776 - val_loss: 0.1465
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.1623 - val_loss: 0.1570
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1937 - val_loss: 0.1490
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1764 - val_loss: 0.1468
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.1884 - val_loss: 0.1511
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - loss: 0.1610 - val_loss: 0.1447
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.1764 - val_loss: 0.1449
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1660 - val_loss: 0.1397
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1844 - val_loss: 0.1431
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 0.1635 - val_loss: 0.1390
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.1633 - val_loss: 0.1377
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.1654 - val_loss: 0.1359
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.1579 - val_loss: 0.1406
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.1532 - val_loss: 0.1379
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.1556 - val_loss: 0.1338
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1443 - val_loss: 0.1293
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.1398 - val_loss: 0.1268
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - loss: 0.1600 - val_loss: 0.1252
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1321 - val_loss: 0.1227
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1487 - val_loss: 0.1159
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.1248 - val_loss: 0.1156
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - loss: 0.1273 - val_loss: 0.1094
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - loss: 0.1348 - val_loss: 0.1052
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1220 - val_loss: 0.1051
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.1199 - val_loss: 0.1052
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.1085 - val_loss: 0.1029
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.1020 - val_loss: 0.0966
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0983 - val_loss: 0.1029
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.1082 - val_loss: 0.0954
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0947 - val_loss: 0.0956
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0935 - val_loss: 0.0958
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.1029 - val_loss: 0.0966
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.1011 - val_loss: 0.0957
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.1049 - val_loss: 0.0925
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - loss: 0.1010 - val_loss: 0.0880
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - loss: 0.0958 - val_loss: 0.0897

# %%
"""Plot training and validation loss."""
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Make predictions
predicted_sales = model.predict(X)

# Inverse transform to get actual sales values
predicted_sales = scaler.inverse_transform(predicted_sales.reshape(-1, 1))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step

# %%
# Plot the the actual vs predicted results
plt.figure(figsize=(13, 6))
plt.plot(store_data.index[n_step+1:], store_data['Sales'][n_step+1:], 
         label='Actual Sales', color='blue', linestyle='-', linewidth=2)

# Plot the predicted sales
plt.plot(store_data.index[n_step+1:], predicted_sales, 
         label='Predicted Sales', color='orange', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Sales', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.legend()
plt.show()

# %%
# Calculate evaluation metrics
mse = mean_squared_error(store_data['Sales'][n_step+1:], predicted_sales)
mae = mean_absolute_error(store_data['Sales'][n_step+1:], predicted_sales)
rmse = np.sqrt(mse)
#r2=r2_score(store_data['Sales'][n_step+1:], predicted_sales)
#msle=mean_squared_log_error(store_data['Sales'][n_step+1:], predicted_sales)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Squared Error (MSE): 4919671.904581162
# Mean Absolute Error (MAE): 1529.2193296078663
# Mean Squared Error (RMSE): 2218.0333416297335
